# %%
from ultralytics import YOLO
import cv2
from pathlib import Path

# Load YOLO model pre-trained for license plate detection
license_plate_detector = YOLO('license_plate_detector.pt')

# Define the directories
input_dir = Path('img')  # Update this path
output_dir = Path('loq')  # Update this path
output_dir.mkdir(parents=True, exist_ok=True)

# Define the desired size for the cropped license plates
desired_width = 800  # Update this value as needed
desired_height = 400  # Update this value as needed

def detect_and_crop_license_plates(image_path):
    # Read image
    image = cv2.imread(str(image_path))
    if image is None:
        print(f"Failed to load image {image_path}")
        return

    # Detect license plates
    results = license_plate_detector(image)

    # Process each detected license plate
    for i, result in enumerate(results):
        boxes = result.boxes.xyxy.numpy()
        classes = result.boxes.cls.numpy().astype(int)

        for j, box in enumerate(boxes):
            x1, y1, x2, y2 = map(int, box[:4])
            class_id = classes[j]

            # Ensure we are detecting a license plate (class 0 for 'license plate')
            if class_id == 0:  # Assuming class 0 is 'license plate'
                # Crop the detected area
                crop_img = image[y1:y2, x1:x2]

                # Resize the cropped image
                resized_img = cv2.resize(crop_img, (desired_width, desired_height), interpolation=cv2.INTER_CUBIC)

                # Save the resized cropped image
                crop_filename = f'{image_path.stem}_plate_{i}.jpg'
                cv2.imwrite(str(output_dir / crop_filename), resized_img, [cv2.IMWRITE_JPEG_QUALITY, 95])
                print(f'Saved resized cropped license plate to {crop_filename}')

# Iterate over all images in the input directory
for img_file in input_dir.glob('*.jpg'):
    detect_and_crop_license_plates(img_file)

print("Finished processing all images.")
# Out:
# 0: 640x640 2 license_plates, 439.8ms
# Speed: 13.0ms preprocess, 439.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Saved resized cropped license plate to cam1_39_plate_0.jpg
# Saved resized cropped license plate to cam1_39_plate_0.jpg
#
# 0: 448x640 1 license_plate, 259.8ms
# Speed: 6.1ms preprocess, 259.8ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Saved resized cropped license plate to cam1_33_plate_0.jpg
#
# 0: 640x640 1 license_plate, 359.7ms
# Speed: 6.7ms preprocess, 359.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Saved resized cropped license plate to cam1_8_plate_0.jpg
#
# 0: 640x544 1 license_plate, 306.9ms
# Speed: 7.2ms preprocess, 306.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 544)
# Saved resized cropped license plate to cam1_27_plate_0.jpg
#
# 0: 480x640 1 license_plate, 267.5ms
# Speed: 4.3ms preprocess, 267.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Saved resized cropped license plate to cam1_46_plate_0.jpg
#
# 0: 640x480 1 license_plate, 276.9ms
# Speed: 4.7ms preprocess, 276.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# Saved resized cropped license plate to cam1_6_plate_0.jpg
#
# 0: 640x480 1 license_plate, 260.0ms
# Speed: 5.2ms preprocess, 260.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# Saved resized cropped license plate to cam1_15_plate_0.jpg
#
# 0: 640x480 1 license_plate, 255.3ms
# Speed: 4.7ms preprocess, 255.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# Saved resized cropped license plate to cam1_3_plate_0.jpg
#
# 0: 480x640 1 license_plate, 224.7ms
# Speed: 6.7ms preprocess, 224.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Saved resized cropped license plate to cam1_40_plate_0.jpg
#
# 0: 640x384 1 license_plate, 133.6ms
# Speed: 3.8ms preprocess, 133.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Saved resized cropped license plate to cam1_12_plate_0.jpg
#
# 0: 640x480 2 license_plates, 159.6ms
# Speed: 5.5ms preprocess, 159.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Saved resized cropped license plate to cam1_19_plate_0.jpg
# Saved resized cropped license plate to cam1_19_plate_0.jpg
#
# 0: 448x640 1 license_plate, 163.5ms
# Speed: 4.8ms preprocess, 163.5ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Saved resized cropped license plate to cam1_32_plate_0.jpg
#
# 0: 640x480 1 license_plate, 157.6ms
# Speed: 4.8ms preprocess, 157.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Saved resized cropped license plate to cam1_35_plate_0.jpg
#
# 0: 640x608 1 license_plate, 192.2ms
# Speed: 6.1ms preprocess, 192.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 608)
# Saved resized cropped license plate to cam1_18_plate_0.jpg
#
# 0: 448x640 1 license_plate, 166.0ms
# Speed: 6.9ms preprocess, 166.0ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Saved resized cropped license plate to cam1_14_plate_0.jpg
#
# 0: 480x640 1 license_plate, 174.3ms
# Speed: 5.1ms preprocess, 174.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved resized cropped license plate to cam1_37_plate_0.jpg
#
# 0: 480x640 2 license_plates, 166.6ms
# Speed: 6.2ms preprocess, 166.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved resized cropped license plate to cam1_28_plate_0.jpg
# Saved resized cropped license plate to cam1_28_plate_0.jpg
#
# 0: 480x640 1 license_plate, 170.8ms
# Speed: 5.4ms preprocess, 170.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Saved resized cropped license plate to cam1_24_plate_0.jpg
#
# 0: 480x640 2 license_plates, 174.0ms
# Speed: 5.5ms preprocess, 174.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Saved resized cropped license plate to cam1_31_plate_0.jpg
# Saved resized cropped license plate to cam1_31_plate_0.jpg
#
# 0: 640x480 (no detections), 185.6ms
# Speed: 5.8ms preprocess, 185.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 license_plate, 180.5ms
# Speed: 7.3ms preprocess, 180.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Saved resized cropped license plate to cam1_16_plate_0.jpg
#
# 0: 480x640 1 license_plate, 171.7ms
# Speed: 6.8ms preprocess, 171.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved resized cropped license plate to cam1_1_plate_0.jpg
#
# 0: 640x480 1 license_plate, 171.4ms
# Speed: 5.8ms preprocess, 171.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Saved resized cropped license plate to cam1_30_plate_0.jpg
#
# 0: 640x416 1 license_plate, 140.6ms
# Speed: 6.0ms preprocess, 140.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
# Saved resized cropped license plate to cam1_13_plate_0.jpg
#
# 0: 640x480 1 license_plate, 173.9ms
# Speed: 3.9ms preprocess, 173.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Saved resized cropped license plate to cam1_44_plate_0.jpg
#
# 0: 480x640 1 license_plate, 158.3ms
# Speed: 4.3ms preprocess, 158.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Saved resized cropped license plate to cam1_2_plate_0.jpg
#
# 0: 480x640 1 license_plate, 157.0ms
# Speed: 4.3ms preprocess, 157.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Saved resized cropped license plate to cam1_38_plate_0.jpg
#
# 0: 640x480 3 license_plates, 162.9ms
# Speed: 4.0ms preprocess, 162.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# Saved resized cropped license plate to cam1_36_plate_0.jpg
# Saved resized cropped license plate to cam1_36_plate_0.jpg
# Saved resized cropped license plate to cam1_36_plate_0.jpg
#
# 0: 480x640 1 license_plate, 171.7ms
# Speed: 6.1ms preprocess, 171.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved resized cropped license plate to cam1_5_plate_0.jpg
#
# 0: 640x608 1 license_plate, 214.8ms
# Speed: 7.2ms preprocess, 214.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
# Saved resized cropped license plate to cam1_23_plate_0.jpg
#
# 0: 384x640 1 license_plate, 140.2ms
# Speed: 3.9ms preprocess, 140.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved resized cropped license plate to cam1_29_plate_0.jpg
#
# 0: 544x640 1 license_plate, 191.4ms
# Speed: 6.0ms preprocess, 191.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# Saved resized cropped license plate to cam1_21_plate_0.jpg
#
# 0: 480x640 1 license_plate, 172.3ms
# Speed: 6.2ms preprocess, 172.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Saved resized cropped license plate to cam1_4_plate_0.jpg
#
# 0: 640x320 (no detections), 150.0ms
# Speed: 5.2ms preprocess, 150.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 384x640 1 license_plate, 145.2ms
# Speed: 5.5ms preprocess, 145.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved resized cropped license plate to cam1_25_plate_0.jpg
#
# 0: 640x480 2 license_plates, 182.3ms
# Speed: 5.6ms preprocess, 182.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Saved resized cropped license plate to cam1_48_plate_0.jpg
# Saved resized cropped license plate to cam1_48_plate_0.jpg
#
# 0: 320x640 1 license_plate, 121.4ms
# Speed: 5.5ms preprocess, 121.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# Saved resized cropped license plate to cam1_26_plate_0.jpg
#
# 0: 640x480 1 license_plate, 176.6ms
# Speed: 6.7ms preprocess, 176.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Saved resized cropped license plate to cam1_42_plate_0.jpg
#
# 0: 576x640 1 license_plate, 211.8ms
# Speed: 7.4ms preprocess, 211.8ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
# Saved resized cropped license plate to cam1_47_plate_0.jpg
#
# 0: 480x640 1 license_plate, 164.3ms
# Speed: 6.1ms preprocess, 164.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved resized cropped license plate to cam1_22_plate_0.jpg
#
# 0: 640x480 (no detections), 165.3ms
# Speed: 5.2ms preprocess, 165.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 480x640 1 license_plate, 159.9ms
# Speed: 5.1ms preprocess, 159.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Saved resized cropped license plate to cam1_10_plate_0.jpg
#
# 0: 640x384 1 license_plate, 148.1ms
# Speed: 4.3ms preprocess, 148.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Saved resized cropped license plate to cam1_34_plate_0.jpg
#
# 0: 576x640 1 license_plate, 210.4ms
# Speed: 6.6ms preprocess, 210.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
# Saved resized cropped license plate to cam1_17_plate_0.jpg
#
# 0: 480x640 1 license_plate, 175.4ms
# Speed: 6.3ms preprocess, 175.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Saved resized cropped license plate to cam1_45_plate_0.jpg
#
# 0: 640x384 1 license_plate, 153.3ms
# Speed: 5.7ms preprocess, 153.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Saved resized cropped license plate to cam1_11_plate_0.jpg
#
# 0: 480x640 1 license_plate, 161.8ms
# Speed: 6.2ms preprocess, 161.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved resized cropped license plate to cam1_41_plate_0.jpg
#
# 0: 480x640 1 license_plate, 168.8ms
# Speed: 5.2ms preprocess, 168.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved resized cropped license plate to cam1_20_plate_0.jpg
# Finished processing all images.
