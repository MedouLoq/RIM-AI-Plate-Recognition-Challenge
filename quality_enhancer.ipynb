# %%
import cv2
import numpy as np
import os
from glob import glob
import zipfile
from google.colab import files

def enhance_sharpness(image):
    blurred = cv2.GaussianBlur(image, (0, 0), 3)
    sharp_image = cv2.addWeighted(image, 1.5, blurred, -0.5, 0)
    return sharp_image

def enhance_vibrancy(image):
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hsv_image[:, :, 1] = cv2.add(hsv_image[:, :, 1], 40)  # Increase saturation
    vibrant_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR)
    return vibrant_image

def enhance_contrast(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    l = cv2.equalizeHist(l)
    enhanced_image = cv2.merge((l, a, b))
    enhanced_image = cv2.cvtColor(enhanced_image, cv2.COLOR_LAB2BGR)
    return enhanced_image

def reduce_noise(image):
    denoised_image = cv2.fastNlMeansDenoisingColored(image, None, 10, 10, 7, 21)
    return denoised_image

def enhance_image(image):
    image = enhance_sharpness(image)
    image = enhance_vibrancy(image)
    image = enhance_contrast(image)
    image = reduce_noise(image)
    return image

def process_images(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        print(f"Created output directory: {output_folder}")

    image_paths = glob(os.path.join(input_folder, '*.jpg')) + \
                  glob(os.path.join(input_folder, '*.png')) + \
                  glob(os.path.join(input_folder, '*.jpeg'))

    if not image_paths:
        print(f"No images found in the input folder: {input_folder}")
        return

    print(f"Found {len(image_paths)} images in the input folder.")

    for image_path in image_paths:
        print(f"Processing {image_path}")
        image = cv2.imread(image_path)
        if image is None:
            print(f"Failed to read {image_path}")
            continue

        enhanced_image = enhance_image(image)
        output_path = os.path.join(output_folder, os.path.basename(image_path))
        cv2.imwrite(output_path, enhanced_image)
        print(f"Saved enhanced image to {output_path}")

def zip_folder(folder_path, zip_path):
    with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, _, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, folder_path))
    print(f"Created zip file: {zip_path}")

input_folder = 'img'  # Update this path
output_folder = 'img_enhanced'  # Update this path
zip_path = 'img_enhanced.zip'  # Path to save the zip file

process_images(input_folder, output_folder)
zip_folder(output_folder, zip_path)

# Download the zip file
files.download(zip_path)
# Out:
# Created output directory: img_enhanced
# Found 734 images in the input folder.
# Processing img/web1_26.jpg
# Saved enhanced image to img_enhanced/web1_26.jpg
# Processing img/web1_147.jpg
# Saved enhanced image to img_enhanced/web1_147.jpg
# Processing img/web1_375.jpg
# Saved enhanced image to img_enhanced/web1_375.jpg
# Processing img/web1_67.jpg
# Saved enhanced image to img_enhanced/web1_67.jpg
# Processing img/web1_525.jpg
# Saved enhanced image to img_enhanced/web1_525.jpg
# Processing img/web1_491.jpg
# Saved enhanced image to img_enhanced/web1_491.jpg
# Processing img/web1_282.jpg
# Saved enhanced image to img_enhanced/web1_282.jpg
# Processing img/web1_529.jpg
# Saved enhanced image to img_enhanced/web1_529.jpg
# Processing img/web1_690.jpg
# Saved enhanced image to img_enhanced/web1_690.jpg
# Processing img/web1_561.jpg
# Saved enhanced image to img_enhanced/web1_561.jpg
# Processing img/web1_103.jpg
# Saved enhanced image to img_enhanced/web1_103.jpg
# Processing img/web1_554.jpg
# Saved enhanced image to img_enhanced/web1_554.jpg
# Processing img/web1_656.jpg
# Saved enhanced image to img_enhanced/web1_656.jpg
# Processing img/web1_90.jpg
# Saved enhanced image to img_enhanced/web1_90.jpg
# Processing img/web1_152.jpg
# Saved enhanced image to img_enhanced/web1_152.jpg
# Processing img/web1_131.jpg
# Saved enhanced image to img_enhanced/web1_131.jpg
# Processing img/web1_433.jpg
# Saved enhanced image to img_enhanced/web1_433.jpg
# Processing img/web1_443.jpg
# Saved enhanced image to img_enhanced/web1_443.jpg
# Processing img/web1_732.jpg
# Saved enhanced image to img_enhanced/web1_732.jpg
# Processing img/web1_352.jpg
# Saved enhanced image to img_enhanced/web1_352.jpg
# Processing img/web1_581.jpg
# Saved enhanced image to img_enhanced/web1_581.jpg
# Processing img/web1_701.jpg
# Saved enhanced image to img_enhanced/web1_701.jpg
# Processing img/web1_558.jpg
# Saved enhanced image to img_enhanced/web1_558.jpg
# Processing img/web1_428.jpg
# Saved enhanced image to img_enhanced/web1_428.jpg
# Processing img/web1_533.jpg
# Saved enhanced image to img_enhanced/web1_533.jpg
# Processing img/web1_703.jpg
# Saved enhanced image to img_enhanced/web1_703.jpg
# Processing img/web1_531.jpg
# Saved enhanced image to img_enhanced/web1_531.jpg
# Processing img/web1_329.jpg
# Saved enhanced image to img_enhanced/web1_329.jpg
# Processing img/web1_63.jpg
# Saved enhanced image to img_enhanced/web1_63.jpg
# Processing img/web1_176.jpg
# Saved enhanced image to img_enhanced/web1_176.jpg
# Processing img/web1_633.jpg
# Saved enhanced image to img_enhanced/web1_633.jpg
# Processing img/web1_478.jpg
# Saved enhanced image to img_enhanced/web1_478.jpg
# Processing img/web1_638.jpg
# Saved enhanced image to img_enhanced/web1_638.jpg
# Processing img/web1_393.jpg
# Saved enhanced image to img_enhanced/web1_393.jpg
# Processing img/web1_17.jpg
# Saved enhanced image to img_enhanced/web1_17.jpg
# Processing img/web1_279.jpg
# Saved enhanced image to img_enhanced/web1_279.jpg
# Processing img/web1_681.jpg
# Failed to read img/web1_681.jpg
# Processing img/web1_604.jpg
# Saved enhanced image to img_enhanced/web1_604.jpg
# Processing img/web1_475.jpg
# Saved enhanced image to img_enhanced/web1_475.jpg
# Processing img/web1_311.jpg
# Saved enhanced image to img_enhanced/web1_311.jpg
# Processing img/web1_392.jpg
# Saved enhanced image to img_enhanced/web1_392.jpg
# Processing img/web1_499.jpg
# Saved enhanced image to img_enhanced/web1_499.jpg
# Processing img/web1_527.jpg
# Saved enhanced image to img_enhanced/web1_527.jpg
# Processing img/web1_406.jpg
# Saved enhanced image to img_enhanced/web1_406.jpg
# Processing img/web1_601.jpg
# Saved enhanced image to img_enhanced/web1_601.jpg
# Processing img/web1_683.jpg
# Saved enhanced image to img_enhanced/web1_683.jpg
# Processing img/web1_676.jpg
# Saved enhanced image to img_enhanced/web1_676.jpg
# Processing img/web1_597.jpg
# Saved enhanced image to img_enhanced/web1_597.jpg
# Processing img/web1_182.jpg
# Saved enhanced image to img_enhanced/web1_182.jpg
# Processing img/web1_734.jpg
# Saved enhanced image to img_enhanced/web1_734.jpg
# Processing img/web1_141.jpg
# Saved enhanced image to img_enhanced/web1_141.jpg
# Processing img/web1_254.jpg
# Saved enhanced image to img_enhanced/web1_254.jpg
# Processing img/web1_122.jpg
# Saved enhanced image to img_enhanced/web1_122.jpg
# Processing img/web1_350.jpg
# Saved enhanced image to img_enhanced/web1_350.jpg
# Processing img/web1_479.jpg
# Saved enhanced image to img_enhanced/web1_479.jpg
# Processing img/web1_298.jpg
# Saved enhanced image to img_enhanced/web1_298.jpg
# Processing img/web1_482.jpg
# Saved enhanced image to img_enhanced/web1_482.jpg
# Processing img/web1_49.jpg
# Saved enhanced image to img_enhanced/web1_49.jpg
# Processing img/web1_513.jpg
# Saved enhanced image to img_enhanced/web1_513.jpg
# Processing img/web1_10.jpg
# Saved enhanced image to img_enhanced/web1_10.jpg
# Processing img/web1_557.jpg
# Saved enhanced image to img_enhanced/web1_557.jpg
# Processing img/web1_705.jpg
# Saved enhanced image to img_enhanced/web1_705.jpg
# Processing img/web1_207.jpg
# Saved enhanced image to img_enhanced/web1_207.jpg
# Processing img/web1_665.jpg
# Saved enhanced image to img_enhanced/web1_665.jpg
# Processing img/web1_586.jpg
# Saved enhanced image to img_enhanced/web1_586.jpg
# Processing img/web1_369.jpg
# Saved enhanced image to img_enhanced/web1_369.jpg
# Processing img/web1_516.jpg
# Saved enhanced image to img_enhanced/web1_516.jpg
# Processing img/web1_28.jpg
# Saved enhanced image to img_enhanced/web1_28.jpg
# Processing img/web1_420.jpg
# Saved enhanced image to img_enhanced/web1_420.jpg
# Processing img/web1_238.jpg
# Saved enhanced image to img_enhanced/web1_238.jpg
# Processing img/web1_400.jpg
# Saved enhanced image to img_enhanced/web1_400.jpg
# Processing img/web1_580.jpg
# Saved enhanced image to img_enhanced/web1_580.jpg
# Processing img/web1_457.jpg
# Saved enhanced image to img_enhanced/web1_457.jpg
# Processing img/web1_61.jpg
# Saved enhanced image to img_enhanced/web1_61.jpg
# Processing img/web1_625.jpg
# Saved enhanced image to img_enhanced/web1_625.jpg
# Processing img/web1_13.jpg
# Saved enhanced image to img_enhanced/web1_13.jpg
# Processing img/web1_687.jpg
# Saved enhanced image to img_enhanced/web1_687.jpg
# Processing img/web1_62.jpg
# Saved enhanced image to img_enhanced/web1_62.jpg
# Processing img/web1_425.jpg
# Saved enhanced image to img_enhanced/web1_425.jpg
# Processing img/web1_612.jpg
# Saved enhanced image to img_enhanced/web1_612.jpg
# Processing img/web1_60.jpg
# Saved enhanced image to img_enhanced/web1_60.jpg
# Processing img/web1_340.jpg
# Saved enhanced image to img_enhanced/web1_340.jpg
# Processing img/web1_537.jpg
# Saved enhanced image to img_enhanced/web1_537.jpg
# Processing img/web1_270.jpg
# Saved enhanced image to img_enhanced/web1_270.jpg
# Processing img/web1_226.jpg
# Saved enhanced image to img_enhanced/web1_226.jpg
# Processing img/web1_126.jpg
# Saved enhanced image to img_enhanced/web1_126.jpg
# Processing img/web1_623.jpg
# Saved enhanced image to img_enhanced/web1_623.jpg
# Processing img/web1_169.jpg
# Saved enhanced image to img_enhanced/web1_169.jpg
# Processing img/web1_664.jpg
# Saved enhanced image to img_enhanced/web1_664.jpg
# Processing img/web1_697.jpg
# Saved enhanced image to img_enhanced/web1_697.jpg
# Processing img/web1_80.jpg
# Saved enhanced image to img_enhanced/web1_80.jpg
# Processing img/web1_363.jpg
# Saved enhanced image to img_enhanced/web1_363.jpg
# Processing img/web1_134.jpg
# Saved enhanced image to img_enhanced/web1_134.jpg
# Processing img/web1_242.jpg
# Saved enhanced image to img_enhanced/web1_242.jpg
# Processing img/web1_398.jpg
# Saved enhanced image to img_enhanced/web1_398.jpg
# Processing img/web1_159.jpg
# Saved enhanced image to img_enhanced/web1_159.jpg
# Processing img/web1_334.jpg
# Saved enhanced image to img_enhanced/web1_334.jpg
# Processing img/web1_376.jpg
# Saved enhanced image to img_enhanced/web1_376.jpg
# Processing img/web1_550.jpg
# Saved enhanced image to img_enhanced/web1_550.jpg
# Processing img/web1_64.jpg
# Saved enhanced image to img_enhanced/web1_64.jpg
# Processing img/web1_384.jpg
# Saved enhanced image to img_enhanced/web1_384.jpg
# Processing img/web1_727.jpg
# Saved enhanced image to img_enhanced/web1_727.jpg
# Processing img/web1_698.jpg
# Saved enhanced image to img_enhanced/web1_698.jpg
# Processing img/web1_14.jpg
# Saved enhanced image to img_enhanced/web1_14.jpg
# Processing img/web1_3.jpg
# Saved enhanced image to img_enhanced/web1_3.jpg
# Processing img/web1_314.jpg
# Saved enhanced image to img_enhanced/web1_314.jpg
# Processing img/web1_294.jpg
# Saved enhanced image to img_enhanced/web1_294.jpg
# Processing img/web1_497.jpg
# Saved enhanced image to img_enhanced/web1_497.jpg
# Processing img/web1_362.jpg
# Saved enhanced image to img_enhanced/web1_362.jpg
# Processing img/web1_283.jpg
# Saved enhanced image to img_enhanced/web1_283.jpg
# Processing img/web1_44.jpg
# Saved enhanced image to img_enhanced/web1_44.jpg
# Processing img/web1_250.jpg
# Saved enhanced image to img_enhanced/web1_250.jpg
# Processing img/web1_284.jpg
# Saved enhanced image to img_enhanced/web1_284.jpg
# Processing img/web1_120.jpg
# Saved enhanced image to img_enhanced/web1_120.jpg
# Processing img/web1_83.jpg
# Saved enhanced image to img_enhanced/web1_83.jpg
# Processing img/web1_117.jpg
# Saved enhanced image to img_enhanced/web1_117.jpg
# Processing img/web1_380.jpg
# Saved enhanced image to img_enhanced/web1_380.jpg
# Processing img/web1_225.jpg
# Saved enhanced image to img_enhanced/web1_225.jpg
# Processing img/web1_424.jpg
# Saved enhanced image to img_enhanced/web1_424.jpg
# Processing img/web1_214.jpg
# Saved enhanced image to img_enhanced/web1_214.jpg
# Processing img/web1_190.jpg
# Saved enhanced image to img_enhanced/web1_190.jpg
# Processing img/web1_689.jpg
# Saved enhanced image to img_enhanced/web1_689.jpg
# Processing img/web1_365.jpg
# Saved enhanced image to img_enhanced/web1_365.jpg
# Processing img/web1_317.jpg
# Saved enhanced image to img_enhanced/web1_317.jpg
# Processing img/web1_150.jpg
# Saved enhanced image to img_enhanced/web1_150.jpg
# Processing img/web1_459.jpg
# Saved enhanced image to img_enhanced/web1_459.jpg
# Processing img/web1_700.jpg
# Saved enhanced image to img_enhanced/web1_700.jpg
# Processing img/web1_247.jpg
# Saved enhanced image to img_enhanced/web1_247.jpg
# Processing img/web1_357.jpg
# Saved enhanced image to img_enhanced/web1_357.jpg
# Processing img/web1_76.jpg
# Saved enhanced image to img_enhanced/web1_76.jpg
# Processing img/web1_458.jpg
# Saved enhanced image to img_enhanced/web1_458.jpg
# Processing img/web1_211.jpg
# Saved enhanced image to img_enhanced/web1_211.jpg
# Processing img/web1_692.jpg
# Saved enhanced image to img_enhanced/web1_692.jpg
# Processing img/web1_584.jpg
# Saved enhanced image to img_enhanced/web1_584.jpg
# Processing img/web1_576.jpg
# Saved enhanced image to img_enhanced/web1_576.jpg
# Processing img/web1_509.jpg
# Saved enhanced image to img_enhanced/web1_509.jpg
# Processing img/web1_502.jpg
# Saved enhanced image to img_enhanced/web1_502.jpg
# Processing img/web1_436.jpg
# Saved enhanced image to img_enhanced/web1_436.jpg
# Processing img/web1_53.jpg
# Saved enhanced image to img_enhanced/web1_53.jpg
# Processing img/web1_326.jpg
# Saved enhanced image to img_enhanced/web1_326.jpg
# Processing img/web1_372.jpg
# Saved enhanced image to img_enhanced/web1_372.jpg
# Processing img/web1_132.jpg
# Saved enhanced image to img_enhanced/web1_132.jpg
# Processing img/web1_193.jpg
# Saved enhanced image to img_enhanced/web1_193.jpg
# Processing img/web1_456.jpg
# Saved enhanced image to img_enhanced/web1_456.jpg
# Processing img/web1_694.jpg
# Saved enhanced image to img_enhanced/web1_694.jpg
# Processing img/web1_21.jpg
# Saved enhanced image to img_enhanced/web1_21.jpg
# Processing img/web1_313.jpg
# Saved enhanced image to img_enhanced/web1_313.jpg
# Processing img/web1_43.jpg
# Saved enhanced image to img_enhanced/web1_43.jpg
# Processing img/web1_119.jpg
# Saved enhanced image to img_enhanced/web1_119.jpg
# Processing img/web1_710.jpg
# Saved enhanced image to img_enhanced/web1_710.jpg
# Processing img/web1_423.jpg
# Saved enhanced image to img_enhanced/web1_423.jpg
# Processing img/web1_187.jpg
# Saved enhanced image to img_enhanced/web1_187.jpg
# Processing img/web1_12.jpg
# Saved enhanced image to img_enhanced/web1_12.jpg
# Processing img/web1_349.jpg
# Saved enhanced image to img_enhanced/web1_349.jpg
# Processing img/web1_663.jpg
# Saved enhanced image to img_enhanced/web1_663.jpg
# Processing img/web1_133.jpg
# Saved enhanced image to img_enhanced/web1_133.jpg
# Processing img/web1_156.jpg
# Saved enhanced image to img_enhanced/web1_156.jpg
# Processing img/web1_191.jpg
# Saved enhanced image to img_enhanced/web1_191.jpg
# Processing img/web1_290.jpg
# Saved enhanced image to img_enhanced/web1_290.jpg
# Processing img/web1_616.jpg
# Saved enhanced image to img_enhanced/web1_616.jpg
# Processing img/web1_167.jpg
# Saved enhanced image to img_enhanced/web1_167.jpg
# Processing img/web1_50.jpg
# Saved enhanced image to img_enhanced/web1_50.jpg
# Processing img/web1_139.jpg
# Saved enhanced image to img_enhanced/web1_139.jpg
# Processing img/web1_455.jpg
# Saved enhanced image to img_enhanced/web1_455.jpg
# Processing img/web1_269.jpg
# Saved enhanced image to img_enhanced/web1_269.jpg
# Processing img/web1_589.jpg
# Saved enhanced image to img_enhanced/web1_589.jpg
# Processing img/web1_493.jpg
# Saved enhanced image to img_enhanced/web1_493.jpg
# Processing img/web1_297.jpg
# Saved enhanced image to img_enhanced/web1_297.jpg
# Processing img/web1_342.jpg
# Saved enhanced image to img_enhanced/web1_342.jpg
# Processing img/web1_598.jpg
# Saved enhanced image to img_enhanced/web1_598.jpg
# Processing img/web1_539.jpg
# Saved enhanced image to img_enhanced/web1_539.jpg
# Processing img/web1_81.jpg
# Saved enhanced image to img_enhanced/web1_81.jpg
# Processing img/web1_412.jpg
# Saved enhanced image to img_enhanced/web1_412.jpg
# Processing img/web1_575.jpg
# Saved enhanced image to img_enhanced/web1_575.jpg
# Processing img/web1_163.jpg
# Saved enhanced image to img_enhanced/web1_163.jpg
# Processing img/web1_636.jpg
# Saved enhanced image to img_enhanced/web1_636.jpg
# Processing img/web1_124.jpg
# Saved enhanced image to img_enhanced/web1_124.jpg
# Processing img/web1_437.jpg
# Saved enhanced image to img_enhanced/web1_437.jpg
# Processing img/web1_360.jpg
# Saved enhanced image to img_enhanced/web1_360.jpg
# Processing img/web1_177.jpg
# Saved enhanced image to img_enhanced/web1_177.jpg
# Processing img/web1_307.jpg
# Saved enhanced image to img_enhanced/web1_307.jpg
# Processing img/web1_265.jpg
# Saved enhanced image to img_enhanced/web1_265.jpg
# Processing img/web1_599.jpg
# Saved enhanced image to img_enhanced/web1_599.jpg
# Processing img/web1_659.jpg
# Saved enhanced image to img_enhanced/web1_659.jpg
# Processing img/web1_109.jpg
# Saved enhanced image to img_enhanced/web1_109.jpg
# Processing img/web1_707.jpg
# Saved enhanced image to img_enhanced/web1_707.jpg
# Processing img/web1_626.jpg
# Saved enhanced image to img_enhanced/web1_626.jpg
# Processing img/web1_59.jpg
# Saved enhanced image to img_enhanced/web1_59.jpg
# Processing img/web1_41.jpg
# Saved enhanced image to img_enhanced/web1_41.jpg
# Processing img/web1_137.jpg
# Saved enhanced image to img_enhanced/web1_137.jpg
# Processing img/web1_183.jpg
# Saved enhanced image to img_enhanced/web1_183.jpg
# Processing img/web1_644.jpg
# Saved enhanced image to img_enhanced/web1_644.jpg
# Processing img/web1_277.jpg
# Saved enhanced image to img_enhanced/web1_277.jpg
# Processing img/web1_678.jpg
# Saved enhanced image to img_enhanced/web1_678.jpg
# Processing img/web1_536.jpg
# Saved enhanced image to img_enhanced/web1_536.jpg
# Processing img/web1_205.jpg
# Saved enhanced image to img_enhanced/web1_205.jpg
# Processing img/web1_595.jpg
